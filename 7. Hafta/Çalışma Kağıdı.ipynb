# %% [markdown]
# # Problem 1 Aradaki Tam Sayılar
#
# Kullanıcıdan iki adet sayı alınız, bu sayılar arasındaki tam sayıları ekrana yazdıran bir program yazınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
ilk_sayi = int(input("İlk sayıyı girin: "))
ikinci_sayi = int(input("İkinci sayıyı girin: "))

if ilk_sayi <= ikinci_sayi:
    for i in range(ilk_sayi, ikinci_sayi+1):
        print(i)
else:
    for i in range(ikinci_sayi, ilk_sayi+1):
        print(i)

# %% [markdown]
# # Problem 2 Faktöriyel
#
# Kullanıcıdan bir sayı alınız ve alınan sayının faktöriyelini hesaplayan bir program yazınız.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
sayi = int(input("Bir sayı girin: "))
faktoriyel = 1

if sayi < 0:
    print("Negatif sayıların faktöriyeli yoktur.")
elif sayi == 0:
    print("0'ın faktöriyeli 1'dir.")
else:
    for i in range(1, sayi+1):
        faktoriyel *= i
    print(f"{sayi}! = {faktoriyel}")

# %% [markdown]
# # Problem 3 Virgül ile Ayırma
#
# Kullanıcıdan bir metin halinde virgül ile ayrılmış sayılar alınız ve aldığınız her bir sayıyı listeye atayınız, daha sonra listedeki her elemanı toplayıp ekrana bastıran bir program yazınız.
#
# <h4>Sample Input</h4>
# <p>
# Lutfen sayilari virgul ile ayrirarak giriniz: 5,14,7,2,1
# </p>
# <h4>Output</h4>
#
# Toplam: 29

# %%
# 3.Problemin Çözümünü Buraya Yazınız
sayilar = input("Lütfen sayıları virgül ile ayrılarak girin: ")
sayi_listesi = sayilar.split(",")
toplam = 0

for sayi in sayi_listesi:
    toplam += int(sayi)

print("Toplam:", toplam)
# Out:
# Toplam: 84

# %% [markdown]
# # Problem 4 Büyük Sayı
#
# Kullanıcıdan alınan iki sayıdan büyük olanı bulup, ekrana yazdıran bir fonksiyon yazınız.

# %%
# 4.Problemin Çözümünü Buraya Yazınız
sayi1 = float(input("1. Sayı giriniz"))
sayi2 = float(input("2. Sayıyı giriniz"))
def buyuk_sayi_bul(sayi1, sayi2):
    if sayi1 > sayi2:
        return sayi1
    else:
        return sayi2

# %% [markdown]
# # Problem 5 Ürün Kayıt Uygulaması
# Programımız ilk olarak kullanıcıdan, kaydı yapılacak ürünlerin sayısını isteyecek. Ardından yazılmış olan ürün sayısı kadar ürün ismi ve ürün fiyatı bilgisini kullanıcıdan alacak. Son olarak ise ürünleri ekrana yazdıracağız.
#
# <h4>Sample Input:</h4>
# <p>
# Lutfen kac adet urun gireceginizi yaziniz: 3
# <br/>
# 1. Urununuzun ismini giriniz: Mentos
# <br/>
# 1. Urununuzun fiyatini giriniz: 1
# <br/>
# 2. Urununuzun ismini giriniz: Meybuz
# <br/>
# 2. Urununuzun fiyatini giriniz: 0.25
# <br/>
# 3. Urununuzun ismini giriniz: Uzun Şeker
# <br/>
# 3. Urununuzun fiyatini giriniz: 0.75
# <br/>
# <h4>Output:</h4>
# 1. Urun: Mentos - 1 TL
# <br/>
# 2. Urun: Meybuz - 0.25 TL
# <br/>
# 3. Urun: Uzun Şeker - 0.75 TL
# </p>

# %%
# 5.Problemin Çözümünü Buraya Yazınız
urun_sayisi = int(input("Lütfen kaç adet ürün gireceğinizi yazınız: "))
urunler = []

for i in range(urun_sayisi):
    urun_isim = input(f"{i+1}. Ürününüzün ismini giriniz: ")
    urun_fiyat = float(input(f"{i+1}. Ürününüzün fiyatını giriniz: "))
    urunler.append((urun_isim, urun_fiyat))

for i, urun in enumerate(urunler):
    print(f"{i+1}. Ürün: {urun[0]} - {urun[1]} TL")
# Out:
# 1. Ürün: Çikolata - 5.0 TL
# 2. Ürün: Süt - 12.0 TL

# %% [markdown]
# # Problem 6 Türkçe Karakter Çevirici
# Programa girilen dosya ismindeki Türkçe karakterleri, İngilizce'ye çeviren programı yazınız.
#
# <h4>Sample Input:</h4>
# <p>
# Lutfen dosya ismi giriniz: fotoğraf.jpeg
# <br>
# Dosya ismi: fotograf.jpeg
# <br>
# <br>
# Lutfen dosya ismi giriniz: ışık.png
# <br>
# Dosya ismi: isik.png
# </p>

# %%
# 6.Problemin Çözümünü Buraya Yazınız
def convert_filename(filename):
    turkish_chars = "çğıöşüÇĞİÖŞÜ"
    english_equivalents = "cgiosuCGIOSU"
    for i in range(len(turkish_chars)):
        filename = filename.replace(turkish_chars[i], english_equivalents[i])
    return filename

dosya_adi = input("Lütfen dosya ismi giriniz: ")
print("Dosya ismi:", convert_filename(dosya_adi))
# Out:
# Dosya ismi: MeliksahBesir

# %% [markdown]
# # Problem 7 Sayı Tahmin Oyunu ama Bilgisayar Tahmin Ediyor :)
# Sayı tahmin oyunu: İki oyuncudan birinin, 0 ile 100 arasında bir sayı tutması ile başlar. Diğer oyuncu ise tahminler yaparak tutulan sayıyı bulmaya çalışır ve yaptığı her tahminde sayıyı tutmuş olan oyuncudan YUKARI veya AŞAĞI olarak geri bildirim alır. Sayıyı bildiğinde ise rakip oyuncu kaç tahminde (kaç denemede) bildiğini söyler.
#
# Senden yazmanı beklediğimiz program ise Python'ın tahminleri yapan tarafta olacağı bir oyun oluşturman. Yani sen 0 ile 100 arasında bir sayı tutacaksın ardından program senin tuttuğunuz sayıyı bulmaya çalışacak.
# <h4>Sample Input:</h4>
# Bu örnekte aklınızdan 90 tuttuğunuzu varsayalım.
# <p>
# Oyun başlıyor lutfen aklindan bir sayi tut! Tuttun mu, hazır mısın? : 1
# <br>
# Tahmin: 50
# <br>
# Durum: Yukari
# <br>
# Tahmin: 75
# <br>
# Durum: Yukari
# <br>
# Tahmin: 87
# <br>
# Durum: Yukari
# <br>
# Tahmin: 93
# <br>
# Durum: Asagi
# <br>
# Tahmin: 90
# <br>
# Durum: Bildin
# </p>

# %%
# 7.Problemin Çözümünü Buraya Yazınız
import random

def guess_number():
    
    number = random.randint(0, 100)
    
    print("Oyun başlıyor, bir sayı tuttum!")
    
    
    count = 0
    
    
    while True:
        count += 1
        guess = int(input("Tahmin: "))
        
        
        if guess == number:
            print("Durum: Bildin!")
            print("Tebrikler, {} tahminde doğru sayıyı buldun!".format(count))
            break
        
        
        elif guess > number:
            print("Durum: Aşağı")
            
        
        else:
            print("Durum: Yukarı")

guess_number()
# Out:
# Oyun başlıyor, bir sayı tuttum!
# Durum: Yukarı
# Durum: Aşağı
# Durum: Aşağı
# Durum: Yukarı
# Durum: Aşağı
# Durum: Aşağı
# Durum: Bildin!
# Tebrikler, 7 tahminde doğru sayıyı buldun!

# %% [markdown]
# # Problem 8 Net Yaş Hesaplayıcı
#
# Kullanıcının bugünün güncel tarihine kadar yaşadığı ay, gün, yıl süresini hesaplayan bir Python kodu yazınız. (Her ay 30 gün kabul edilmeyecektir. Kodu yazarken hangi ayın kaç gün olduğuna [Şubat ayının 29 gün olduğu yıllar dahil] dikkat edin.)

# %%
# 8.Problemin Çözümünü Buraya Yazınız
import datetime

def calculate_age():
    birthdate = input("Lutfen dogum tarihinizi (gg/aa/yyyy) formatinda giriniz: ")
    birthdate_obj = datetime.datetime.strptime(birthdate, '%d/%m/%Y')
    today = datetime.datetime.today()
    age_years = today.year - birthdate_obj.year
    age_months = today.month - birthdate_obj.month
    age_days = today.day - birthdate_obj.day

    # Ay ve gün hesaplaması
    if age_months < 0:  # Eğer henüz doğum günü gelmediyse
        age_years -= 1
        age_months += 12
    if age_days < 0:  # Eğer henüz doğum günü gelmediyse
        age_months -= 1
        last_month = today.month - 1 if today.month > 1 else 12
        age_days += (today - datetime.datetime(today.year, last_month, today.day)).days
    months_dict = {1: 31, 2: 28, 3: 31, 4: 30, 5: 31, 6: 30, 7: 31, 8: 31, 9: 30, 10: 31, 11: 30, 12: 31}


    if age_months > 0:
        age_days -= months_dict[ today.month - 1 if today.month > 1 else 12]
        if today.month == 3 and ((today.year % 4 == 0 and today.year % 100 != 0) or today.year % 400 == 0):  # Şubat ayı
            age_days -= 1
            if age_days < 0:
                age_days += 29
                age_months -= 1
        else:
            age_days += months_dict[today.month - 1 if today.month > 1 else 12]
            age_months -= 1
    if age_months < 0:
        age_months += 12
        age_years -= 1
    return age_years, age_months, age_days

# Yaş hesaplama işlemini çağır
years, months, days = calculate_age()
print("Bugüne kadar yaşadığınız süre: {} yıl, {} ay ve {} gün".format(years, months, days))
# Out:
# Bugüne kadar yaşadığınız süre: 22 yıl, 1 ay ve 15 gün

# %% [markdown]
# # Problem 9 Tek-Çift
#
# Kullanıcıdan 'q' tuşuna basana kadar rastgele sayılar alın. Tek olanları bir listeye, çift olanları bir başka listeye büyükten küçüğe sıralanacak şekilde atın. Listeleri ekrana yazdıran bir kod yazın.

# %%
# 9.Problemin Çözümünü Buraya Yazınız
odd_numbers = []
even_numbers = []

while True:
    number_input = input("Bir sayı girin (Çıkmak için 'q' ya basın): ")
    
    if number_input == "q":
        break
        
    number = int(number_input)
    
    if number % 2 == 0:
        even_numbers.append(number)
    else:
        odd_numbers.append(number)
        
odd_numbers.sort(reverse=True)
even_numbers.sort(reverse=True)

print("Tek sayılar:", odd_numbers)
print("Çift sayılar:", even_numbers)
# Out:
# Tek sayılar: [93, 5, 5]
# Çift sayılar: [756, 12, 12, 8, 6, 4]

# %% [markdown]
#  # Problem 10 Altıgen Çizimi
#
# Kullanıcıdan altıgenin kaç satırdan oluşacağı ve orta satırında kaç karakter olacağı bilgisini alarak '*' karakteri ile bir altıgen çizin. (For loop kullanabilirsiniz.)

# %%
# 10.Problemin Çözümünü Buraya Yazınız

n = int(input("Altigenin kac satirdan olusacagini girin: "))
m = int(input("Orta satirda kac karakter olacak: "))

for i in range(n):
    if i < n // 2:  # Üst yarısı
        print(' ' * (n - i - 1) + '* ' * (i + 1))
    elif i == n // 2:  # Ortada
        print('* ' * m)
    else:  # Alt yarısı
        print(' ' * (i - n // 2) + '* ' * (n - i))
# Out:
#     *
#    * *
# * * * * *
#  * *
#   *
