# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
user_count = int(input("Kaç kullanıcının giriş yapacağını giriniz: "))
for i in range(user_count):
    name_surname = input("İsim ve soyisminizi giriniz: ")
    age = int(input("Yaşınızı giriniz: "))
    height = float(input("Boyunuzu metre cinsinden giriniz: "))
    weight = float(input("Kilonuzu giriniz: "))
    
    bmi = weight / (height ** 2) # VKİ hesaplama formülü
    
    # VKİ sınıflarını belirleme
    if bmi < 18.5:
        bmi_category = "Zayıf"
    elif bmi < 25:
        bmi_category = "Normal kilolu"
    elif bmi < 30:
        bmi_category = "Fazla kilolu"
    elif bmi < 40:
        bmi_category = "Obez"
    else:
        bmi_category = "İleri derecede obez (morbid obez)"
    
    # Verileri kaydetme
    with open("veriler.txt", "a") as f:
        f.write(f"{name_surname}, {age}, {height}, {weight}, {bmi}, {bmi_category}\n")
        
    # Kullanıcıya VKİ sınıfını gösterme
    print(f"VKİ: {bmi:.2f}, Sınıf: {bmi_category}")

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
def menu():
    print("YetBar Sağlıklı İçecek Otomatı\n")
    print("1. Menüyü Görüntüle")
    print("2. Satın Al")
    print("3. Çıkış")
def secim():
    while True:
        try:
            secim = int(input("Yapmak istediğiniz işlem numarasını giriniz: "))
            if secim < 1 or secim > 3:
                print("Hatalı seçim. Lütfen 1, 2 veya 3 giriniz.")
            else:
                return secim
        except ValueError:
            print("Hatalı seçim. Lütfen sadece sayı giriniz.")
def menu_goruntule():
    menu = {"Yeşil Smoothie": 8, "Meyve Smoothie": 10, "Protein Shake": 12, "Detox Juice": 6}
    print("MENÜ\n")
    for urun, fiyat in menu.items():
        print(urun + ": " + str(fiyat) + " TL")
def satin_al():
    print("Lütfen içeceğinizi seçiniz.\n")
    menu_goruntule()
    while True:
        secim = input("İstediğiniz içeceğin adını giriniz (Çıkış için 'q' giriniz): ")
        if secim.lower() == "q":
            return
        menu = {"Yeşil Smoothie": 8, "Meyve Smoothie": 10, "Protein Shake": 12, "Detox Juice": 6}
        if secim not in menu:
            print("Hatalı seçim. Lütfen menüden bir içecek seçiniz.")
        else:
            adet = 0
            while True:
                try:
                    adet = int(input("Kaç adet " + secim + " istiyorsunuz?: "))
                    if adet < 1:
                        print("En az 1 adet seçmelisiniz.")
                    else:
                        break
                except ValueError:
                    print("Hatalı giriş. Lütfen sadece sayı giriniz.")
            fiyat = menu[secim] * adet
            print(str(adet) + " adet " + secim + " için ödemeniz gereken tutar: " + str(fiyat) + " TL\n")
            kaydet(secim, adet, fiyat)
