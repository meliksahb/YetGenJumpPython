# %%
print("Hello World")
"hello python"
print("hello","hello",sep = ",")
print("YetGen Dikeyine Hoş Geldiniz", end = ".")
print(3.14)
#tekli yorum satırı

print("hava harbi soğuk") #print ekrana yazıyor
print("----") #ilk video burada bitiyor

print("YetGen")
print("YetGen")
print("YetGen")
yetgen = "YetGen Jump"
print(yetgen)
print(yetgen)
print(yetgen)
mel_1 = "Meliksah"
print(mel_1)
isimSoyisim = "Melikşah Beşir" #camel case
isim_soyisim = "aa bb" #snake case
print(isimSoyisim)
print(isim_soyisim)
print(type("Meliksah"))
type(1)
type(True)
type(3.14)
print("----") #ikinci video burada bitiyor

print(10)
print(type(10))
g = 9.81
print(g)
print(type(g))
a = 4
b = 3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(2 **3)
print(a % b)
print(a // b)
var = "Merhaba"
print(var)
var2 = 'hebele hübele'
print(var2)
print(var2[0])
print(var2[-1])
isim = "Meliksah"
soyisim = "Besir"
yas = 23
print(isim + " " + soyisim)
print(isim, "", soyisim, " ", yas)
jettReviveMe = False
print(jettReviveMe)
print(type(jettReviveMe))
isim = input("İsim giriniz : ")
print(f"Merhaba {isim}")
print("merhaba", isim)
print("merhaba " + isim)
sayi1 = int(input("Birinci sayıyı giriniz : "))
sayi2 = int(input("ikinci sayı : "))
print(sayi1+sayi2)
print("----") #üçüncü video burada bitiyor
# Out:
# Hello World
# hello,hello
# YetGen Dikeyine Hoş Geldiniz.3.14
# hava harbi soğuk
# ----
# YetGen
# YetGen
# YetGen
# YetGen Jump
# YetGen Jump
# YetGen Jump
# Meliksah
# Melikşah Beşir
# aa bb
# <class 'str'>
# ----
# 10
# <class 'int'>
# 9.81
# <class 'float'>
# 7
# 1
# 12
# 1.3333333333333333
# 8
# 1
# 1
# Merhaba
# hebele hübele
# h
# e
# Meliksah Besir
# Meliksah  Besir   23
# False
# <class 'bool'>
# Merhaba a
# merhaba a
# merhaba a
# 9
# ----
