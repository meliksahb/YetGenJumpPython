# %% [markdown]
# # Problem 1
#
# Kumanda isminde bir sınıf oluşturarak aşağıdaki işlemleri yapmasını sağlayan fonksiyonları sınıf içerisinde yazalım.
# 1. Tv Aç
# 2. Tv Kapat
# 3. Ses Ayarları
# 4. Kanal Ekle
# 5. Kanal Sayısını Öğrenme
# 6. Rastgele Kanala Geçme
# 7. Televizyon Bilgileri
#
#
# Kumandayı kapatmak için q tuşuna basılmalı ve diğer durumlarda hangi işlemi yapmak istediği sorulmalıdır. Her işlemde gerekli fonksiyonunun sınıf içerisinden çağırılması gerekmektedir.
#
# random ve time kütüphanesini araştırarak kullanabilirsiniz.
#
# Kendi istediğiniz özellikleri eklemekte serbetsiniz.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
import random
import time

class Kumanda:
    def __init__(self):
        self.tv_durumu = False
        self.ses = 50
        self.kanal_listesi = ["TRT", "ATV", "FOX", "KANAL D", "STAR"]
        self.secili_kanal = "TRT"

    def tv_ac(self):
        if self.tv_durumu:
            print("Televizyon zaten açık")
        else:
            self.tv_durumu = True
            print("Televizyon açıldı")

    def tv_kapat(self):
        if self.tv_durumu:
            self.tv_durumu = False
            print("Televizyon kapatıldı")
        else:
            print("Televizyon zaten kapalı")

    def ses_ayarları(self):
        while True:
            cevap = input("Sesi azalt: '<'\nSesi artır: '>'\nÇıkış yapmak için q'ya basın\n")
            if cevap == "<":
                if self.ses != 0:
                    self.ses -= 1
                    print("Ses:", self.ses)
            elif cevap == ">":
                if self.ses != 100:
                    self.ses += 1
                    print("Ses:", self.ses)
            elif cevap == "q":
                print("Ses güncellendi:", self.ses)
                break

    def kanal_ekle(self, kanal_ismi):
        self.kanal_listesi.append(kanal_ismi)
        print("Kanal eklendi")

    def kanal_sayisi(self):
        print("Toplam", len(self.kanal_listesi), "kanal var")

    def rastgele_kanal(self):
        rastgele = random.randint(0, len(self.kanal_listesi)-1)
        self.secili_kanal = self.kanal_listesi[rastgele]
        print("Şu anki kanal:", self.secili_kanal)

    def televizyon_bilgileri(self):
        print("""
        Televizyon Durumu: {}
        Ses: {}
        Şu anki kanal: {}
        Kanal Listesi: {}
        """.format(self.tv_durumu, self.ses, self.secili_kanal, self.kanal_listesi))

kumanda = Kumanda()

print("""
Televizyon Kumandası

1. Tv Aç
2. Tv Kapat
3. Ses Ayarları
4. Kanal Ekle
5. Kanal Sayısını Öğrenme
6. Rastgele Kanala Geçme
7. Televizyon Bilgileri

Çıkmak için 'q'ya basın
""")

while True:
    islem = input("İşlemi seçin: ")

    if islem == "q":
        print("Programdan çıkılıyor...")
        time.sleep(1)
        break

    elif islem == "1":
        kumanda.tv_ac()

    elif islem == "2":
        kumanda.tv_kapat()

    elif islem == "3":
        kumanda.ses_ayarları()

    elif islem == "4":
        kanal_isimleri = input("Kanal isimlerini ',' ile ayırarak girin: ")
        kanal_listesi = kanal_isimleri.split(",")
        for kanal in kanal_listesi
